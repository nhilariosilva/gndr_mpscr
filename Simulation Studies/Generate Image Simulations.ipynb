# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as mcolors
import matplotlib.gridspec as gridspec
import seaborn as sns
import random

from time import time

from scipy.special import comb, loggamma, lambertw
from scipy.stats import multinomial, expon, beta
from scipy.ndimage import gaussian_filter

from sklearn.model_selection import train_test_split

import lifelines
from lifelines.utils import concordance_index
from lifelines.statistics import logrank_test

from silence_tensorflow import silence_tensorflow
silence_tensorflow()
import tensorflow as tf
import tensorflow_probability as tfp
from tensorflow import keras
from tensorflow.keras import optimizers, initializers, regularizers, layers

config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.compat.v1.Session(config = config)

import os, shutil, sys
from pathlib import Path
import json
import subprocess
from tqdm import tqdm

import thetaflow as thf
# import modelnn2 as thf
print("Thetaflow version: {}".format(thf.__version__))

sys.path.append("../")
import mpscr_models_flexible as mpscr
import pwexp_flexible as pwexp
import gndr_utils as utils
import mps
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1786111362.875842   15748 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1786111364.758585   15748 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Thetaflow version: 0.0.35

# %% [markdown]
# # Notebook

# %% [markdown]
# In this notebook, we load the traditional MNIST dataset in order to benchmark and study the performance of our new model under images as predicting variables.
#
# This dataset is very well known, consisting on the basic identification of numbers in images. We will be considering that the number disposed in each image corresponds to 10 times the susceptible probability of a simulated individual. That is, if the image corresponds to a 3, then the simulated time associated to it will have a 0.3 probability of being susceptible to death.
#
# With that simulation, we aim to study the capacity of the MPScr to select the true, generating model out of all alternative proposals and also study some asymptotic properties of such model.

# %%
def generate_synthetic_brain(omega, size = 200):
    """
        Generates a synthetic 200x200 brain mask with Alzheimer's-like atrophy.
        
        Parameters:
            omega (float): Disease severity from 0.0 (Healthy) to 1.0 (Severe AD).
            size (int): The dimension of the output image (size x size).
    """
    x = np.linspace(-1, 1, size)
    y = np.linspace(-1, 1, size)
    X, Y = np.meshgrid(x, y)
    
    # Define the base "Healthy" brain shape (an oval/ellipse)
    # R_cortex represents the distance from the center
    R_cortex = np.sqrt((X / 0.95)**2 + (Y / 0.85)**2)
    
    # Procedural Noise for Cortical Rugosity
    # We create random noise and heavily blur it to make it smooth and organic
    raw_noise = np.random.rand(size, size)
    smooth_noise = gaussian_filter(raw_noise, sigma = 4)
    # Normalize the noise to have a mean of 0 and std of 1
    smooth_noise = (smooth_noise - np.mean(smooth_noise)) / np.std(smooth_noise)
    
    # Atrophy to the Cortex Boundary
    # Omega dictates how aggressively the noise "eats" into the outer edge
    atrophy_factor = omega * 0.1 + 0.01
    distorted_cortex = R_cortex + atrophy_factor * smooth_noise
    cortex_mask = distorted_cortex < 1.0
    
    # Ventricular Enlargement (Holes in the center)
    # Ventricles grow larger and more distorted as omega increases
    ventricle_base_width = 0.30 + (omega * 0.25)
    ventricle_base_height = 0.15 + (omega * 0.15)
    R_ventricles = np.sqrt((X / ventricle_base_width)**2 + (Y / ventricle_base_height)**2)
    
    # Different noise map for the ventricles so they evolve independently
    v_raw_noise = np.random.rand(size, size)
    v_noise = gaussian_filter(v_raw_noise, sigma = 4)
    v_noise = (v_noise - np.mean(v_noise)) / np.std(v_noise)

    v_atrophy_factor = omega * 0.2
    distorted_ventricles = R_ventricles + v_atrophy_factor * v_noise
    ventricle_mask = distorted_ventricles < 1.0
    
    # Brain tissue is the cortex minus the ventricles
    brain_mask = cortex_mask & ~ventricle_mask

    # Obtain the continuous blob that composes our "brain"
    tissue_gradient = np.clip(1.0 - distorted_cortex, 0, 1)
    
    # Tissue Texture: Higher-frequency noise for "folds"
    t_raw_noise = np.random.rand(size, size)
    texture_noise = gaussian_filter(t_raw_noise, sigma = 3) # Lower sigma = finer details
    texture_noise = (texture_noise - np.mean(texture_noise)) / np.std(texture_noise)
    
    # Combine and normalize strictly between 0 and 1
    tissue_density = tissue_gradient + 0.3 * texture_noise
    min_val = np.min(tissue_density[brain_mask])
    max_val = np.max(tissue_density[brain_mask])
    tissue_density = (tissue_density - min_val) / (max_val - min_val)
    
    # Quantize into 4 discrete gray tones: 0.25, 0.50, 0.75, 1.00
    # (tissue_density * 3) ranges from 0 to 3. Rounding and math shifts it to our 4 bins.
    quantized_tissue = np.round(tissue_density * 5)
    quantized_tissue = (quantized_tissue + 1) / 4.0 

    # final_brain = np.where(brain_mask, quantized_tissue, 0.0)
    
    # Initialize an all-black background for the ventricles
    final_brain = np.zeros((size, size), dtype = np.float32)
    
    # Paint the tissue
    final_brain[brain_mask] = quantized_tissue[brain_mask]

    # Makes the ventricles slighlty clearer than the background
    white_intensity = 0.2 # Ensures it is the absolute brightest feature
    final_brain[cortex_mask & ventricle_mask] = white_intensity

    # Normalize the image pixels to be between 0 and 1
    final_brain = final_brain / np.max(final_brain)
    
    return final_brain.astype(np.float32)

# %%
import numpy as np
from scipy.ndimage import gaussian_filter

def generate_synthetic_brain(omega, height = 140, width = 180):
    """
        Generates a synthetic brain mask with Alzheimer's-like atrophy.
        
        Parameters:
            omega (float): Disease severity from 0.0 (Healthy) to 1.0 (Severe AD).
            height (int): The vertical dimension of the output image.
            width (int): The horizontal dimension of the output image.
    """
    omega = omega * 1.5
    
    # Map the grid to the new distinct width and height dimensions
    x = np.linspace(-1, 1, width)
    y = np.linspace(-1, 1, height)
    X, Y = np.meshgrid(x, y)
    
    # Define the base Healthy brain shape
    R_cortex = np.sqrt((X / 0.95)**2 + (Y / 0.85)**2)
    
    # Procedural Noise for Cortical Rugosity
    raw_noise = np.random.rand(height, width)
    smooth_noise = gaussian_filter(raw_noise, sigma = 4)
    smooth_noise = (smooth_noise - np.mean(smooth_noise)) / np.std(smooth_noise)
    
    # Atrophy to the Cortex Boundary
    atrophy_factor = omega * 0.1 + 0.01
    distorted_cortex = R_cortex + atrophy_factor * smooth_noise
    cortex_mask = distorted_cortex < 1.0
    
    # Ventricular Enlargement
    ventricle_base_width = 0.30 + (omega * 0.25)
    ventricle_base_height = 0.15 + (omega * 0.15)
    R_ventricles = np.sqrt((X / ventricle_base_width)**2 + (Y / ventricle_base_height)**2)
    
    v_raw_noise = np.random.rand(height, width)
    v_noise = gaussian_filter(v_raw_noise, sigma = 4)
    v_noise = (v_noise - np.mean(v_noise)) / np.std(v_noise)
    v_atrophy_factor = omega * 0.2
    distorted_ventricles = R_ventricles + v_atrophy_factor * v_noise
    ventricle_mask = distorted_ventricles < 1.0
    
    brain_mask = cortex_mask & ~ventricle_mask

    # Control the color gradient inside the brain
    # It only begins to fade to darker colors at the outer edges.
    base_intensity = np.clip((1.0 - distorted_cortex) * 3.0, 0, 1)
    
    # Tissue Texture
    t_raw_noise = np.random.rand(height, width)
    texture_noise = gaussian_filter(t_raw_noise, sigma = 3) 
    texture_noise = (texture_noise - np.mean(texture_noise)) / np.std(texture_noise)
    
    # Radial weight mask for the noise
    # This evaluates to 0 in the center and ramps up to 1 near the cortex boundary.
    noise_weight = np.clip((distorted_cortex - 0.5) * 2.5, 0, 1)
    
    # The center gets 0 noise, preserving the white intensity.
    tissue_density = base_intensity + (0.3 * texture_noise * noise_weight)

    min_val = np.min(tissue_density[brain_mask])
    max_val = np.max(tissue_density[brain_mask])
    tissue_density = (tissue_density - min_val) / (max_val - min_val)
    
    # Quantize into 4 discrete gray tones
    quantized_tissue = np.round(tissue_density * 5)
    quantized_tissue = (quantized_tissue + 1) / 4.0 

    final_brain = np.zeros((height, width), dtype = np.float32)
    
    # Paint the tissue
    final_brain[brain_mask] = quantized_tissue[brain_mask]

    # Makes the ventricles slightly clearer than the background
    white_intensity = 0.2 
    final_brain[cortex_mask & ventricle_mask] = white_intensity

    # Normalize the image pixels to be between 0 and 1
    final_brain = final_brain / np.max(final_brain)
    
    return final_brain.astype(np.float32)

# %%
# Different severity levels for brain generation
omegas = [0.01, 0.2, 0.4, 0.6, 0.8, 0.99]

np.random.seed(10)

fig, axes = plt.subplots(2, 3, figsize=(10, 6))
fig.suptitle("Synthetic Alzheimer's Progression (200x200)", fontsize=16)

for ax, omega in zip(axes.flatten(), omegas):
    brain = generate_synthetic_brain(omega)
    ax.imshow(brain, cmap = 'gray')
    ax.set_title("Cure p = {:.2f}".format(1-omega))
    
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
def generate_brain_images(p_values, height = 140, width = 180):
    """
        Given different p values for the susceptible probabilities of each patient, we generate their respective brain images
        following the overall literature convention on Alzheimer's brain morphology: atrophied sulci and larger central venticles.
    """
    n = p_values.shape[0]
    brain_imgs = np.zeros( (n, height, width) )
    for j, p in enumerate(p_values):
        brain_imgs[j, :, :] = generate_synthetic_brain(p, height = height, width = width)
    return brain_imgs

# %%
from scipy.stats import beta
np.random.seed(10)

# 200 replicas
R_train = 200
test_size = 0.25

def generate_train_test_imgs( p_train, p_test, test_size = 0.25 ):
    brain_imgs_train = generate_brain_images(1-p_train)
    brain_imgs_test = generate_brain_images(1-p_test)    
    return brain_imgs_train, brain_imgs_test

n_train = 250
n_test = int( n_train * test_size / (1-test_size) )
p_train_250 = beta.rvs( a = 20, b = 3, size = n_train )
p_test_250 = beta.rvs( a = 20, b = 3, size = n_test )

# n_train = 500
# n_test = int( n_train * test_size / (1-test_size) )
# p_train_500 = beta.rvs( a = 20, b = 3, size = n_train )
# p_test_500 = beta.rvs( a = 20, b = 3, size = n_test )

# n_train = 1000
# n_test = int( n_train * test_size / (1-test_size) )
# p_train_1000 = beta.rvs( a = 20, b = 3, size = n_train )
# p_test_1000 = beta.rvs( a = 20, b = 3, size = n_test )

# Single replica for testing functions - Train sizes: {250, 500, 1000}
imgs_train_250, imgs_test_250 = generate_train_test_imgs( p_train_250, p_test_250 )
# imgs_train_500, imgs_test_500 = generate_train_test_imgs( p_train_500, p_test_500 )
# imgs_train_1000, imgs_test_1000 = generate_train_test_imgs( p_train_1000, p_test_1000 )

# %%
def generate_lifetimes_mpscr(model_spec, base_spec, cure_p, alpha, censor_low = 0.0, censor_high = 10.0):
    """
        Specify the latent and base parts of the model being simulated.
        Receives the cure probabilities and the base distribution vector of parameters, alpha.
    """
    n = cure_p.shape[0]
    q = model_spec.fixed_q
    phi = model_spec.phi
    C = model_spec.C
    C_inv = model_spec.C_inv

    y_true = np.repeat(np.inf, n)
    obs_y = y_true.copy()
    
    theta = model_spec.C_inv( model_spec.a0(q) / cure_p, q )
    # Draw U for all patients independently of cured status
    u = np.random.uniform( size = n )
    # If u is lesser than the cure probability, consider those patients as cured
    susceptible_mask = (u >= cure_p)

    # S_pop^{-1} for susceptible patients
    u_susceptible = u[susceptible_mask]
    theta_susceptible = theta[susceptible_mask]    
    ppf_arg = phi(C_inv( C(theta_susceptible, q) * u_susceptible, q ), q) / phi(theta_susceptible, q)
    y_true[susceptible_mask] = base_spec.ppf(ppf_arg, alpha)

    y_censor = np.random.uniform(size = n, low = censor_low, high = censor_high)

    # Define observed lifetimes as 1
    delta = np.zeros(n, dtype = int)
    delta[y_true <= y_censor] = 1
    obs_y[delta == 1] = y_true[delta == 1]
    obs_y[delta == 0] = y_censor[delta == 0]

    cured_status = np.ones(n, dtype=int)
    cured_status[susceptible_mask] = 0
    
    return obs_y, delta, cured_status

# %%
def Spop(model_spec, base_spec, t, p, alpha):
    t_safe = tf.cast( t.copy(), tf.float32 )
    if(len(t.shape) == 1):
        t_safe = tf.reshape(t_safe, shape=(len(t_safe), 1))
            
    # Ensure inputs are already properly unidimensional
    p = tf.cast( tf.squeeze(p), tf.float32 )

    eps = tf.constant(1.0e-5, dtype = tf.float32)
    q = model_spec.fixed_q
    p = tf.clip_by_value(p, eps, 1.0-eps)
    theta = model_spec.C_inv( model_spec.a0(q) / p, q )
    
    # Parts to calculate the final survival curves
    S0_t = tf.reshape( tf.cast( base_spec.survival(t_safe, alpha), tf.float32 ), [-1,1] )
    u_t = S0_t * model_spec.phi(theta, q)
    A_u_t = model_spec.A( u_t, q )
    C_theta = model_spec.C( theta, q )
    # Final survival curve
    S_t = A_u_t / C_theta
    
    return S_t.numpy().T

def fpop(model_spec, base_spec, t, p, alpha):
    t_safe = tf.cast( t.copy(), tf.float32 )
    if(len(t.shape) == 1):
        t_safe = tf.reshape(t_safe, shape=(len(t_safe), 1))
    
    # Ensure inputs are already properly unidimensional
    p = tf.cast( tf.squeeze(p), tf.float32 )

    # Transpose the array of times for broadcasting
    t = t[:,None]

    eps = tf.constant(1.0e-5, dtype = tf.float32)
    q = poisson_spec.fixed_q
    p = tf.clip_by_value(p, eps, 1.0-eps)
    theta = model_spec.C_inv( model_spec.a0(q) / p, q )

    # Parts to calculate the final survival curves
    S0_t = tf.reshape( tf.cast( base_spec.survival(t_safe, alpha), tf.float32 ), [-1,1] )
    f0_t = tf.reshape( tf.cast( base_spec.pdf(t_safe, alpha), tf.float32 ), [-1,1] )
    
    u_t = S0_t * model_spec.phi(theta, q)
    with tf.GradientTape() as tape:
        tape.watch(u_t)
        A_u_t = model_spec.A( u_t, q )
        
    Aprime_u_t = tape.gradient(A_u_t, u_t)
    C_theta = model_spec.C( theta, q )
    # Final density curve
    f_t = A_u_t / C_theta * f0_t * model_spec.phi(theta, q)
    
    return f_t.numpy().T

# %%
def plot_sample(model_spec, base_spec, p, y, delta, cured, alpha, t_low = 0.01, t_high = 10.0, ngrid = 100):
    t = np.linspace(t_low, t_high, ngrid)
    
    Spop_t = Spop(model_spec, base_spec, t, p, alpha = alpha)
    fpop_t = fpop(model_spec, base_spec, t, p, alpha = alpha)
    
    p_susceptibles = p[delta == 1]
    fpop_t_susceptibles = fpop_t[delta == 1, :]
    
    fig, ax = plt.subplots(nrows = 1, ncols = 3, figsize = (16,4), layout = 'constrained')

    norm = mcolors.Normalize(vmin = np.min(p), vmax = np.max(p))
    cmap = plt.get_cmap('jet')
    sm = cm.ScalarMappable(cmap = cmap, norm = norm)
    sm.set_array([])
    
    for i in range(100):
        mapped_color = cmap(norm(p[i]))
        # plt.plot(t, fpop_t_susceptibles[:,i], color = mapped_color, alpha = 0.2)
        # ax.plot(t, fpop_t_susceptibles[:,i], color = mapped_color)
        ax[0].plot(t, fpop_t[i,:], color = mapped_color)
        ax[1].plot(t, fpop_t[i,:], color = mapped_color)
    
    fig.colorbar(sm, ax = ax[1], label='Cure Probability')
    
    dens_pop = fpop_t_susceptibles / np.reshape( (1-p_susceptibles), [-1,1] )
    dens_pop_mixture = np.mean(dens_pop, axis = 0)
    
    sns.histplot(y[(cured == 0) & (delta == 1)], bins = 100, stat = "density", ax = ax[2])
    ax[2].plot(t, dens_pop_mixture, color = "red")
    
    plt.show()

# %%
t = np.linspace(0.01, 10, 100)

poisson_spec = mpscr.MPSPoisson()
weibull_spec = mpscr.BaseWeibull()
k = 2.0
lam = 5.0
alpha = np.array([k, lam])

# %%
np.random.seed(10)

n_train = 10000
n_test = int( n_train * test_size / (1-test_size) )
p_train_1000 = beta.rvs( a = 20, b = 3, size = n_train )
p_test_1000 = beta.rvs( a = 20, b = 3, size = n_test )
# imgs_train_1000, imgs_test_1000 = generate_train_test_imgs( p_train_1000, p_test_1000 )

poisson_spec = mpscr.MPSPoisson()
alpha = np.array([[0.1, 0.05, 0.15, 1, 2]])
s = np.array([0,0.5,1,1.5,2])
pwexp_spec = mpscr.BasePiecewiseExp(4, s = s)

y_train_1000, delta_train_1000, cured_train_1000 = generate_lifetimes_mpscr(poisson_spec, pwexp_spec, p_train_1000, alpha, censor_low = 0.0, censor_high = 20)
y_test_1000, delta_test_1000, cured_test_1000 = generate_lifetimes_mpscr(poisson_spec, pwexp_spec, p_test_1000, alpha, censor_low = 0.0, censor_high = 20)

plot_sample(poisson_spec, pwexp_spec, p_train_1000, y_train_1000, delta_train_1000, cured_train_1000, alpha, t_low = 0.01, t_high = 4.0, ngrid = 100)

# %% [markdown]
# Above, we see an example of data generation from the Poisson promotion time cure model, whose base distribution follows a Piecewise-Exponential with parameter vector $\boldsymbol \alpha = (0.1, 0.05, 0.15, 1, 2)$ and knot points vector $\boldsymbol s = (0, 0.5, 1, 1.5, 2)$. Naturally, in our application of the Alzheimer's dataset, we obtained a reasonable fit by assuming the base distribution to be a simpler Weibull model. Therefore, to match that same pattern in our simulations, we will be assuming the same structure here.

# %%
np.random.seed(1)

poisson_spec = mpscr.MPSPoisson()
exp_spec = mpscr.BaseExponential()
lam = 3.75
alpha = np.array([lam])

n_train = 500
n_test = int( n_train * test_size / (1-test_size) )
p_train = beta.rvs( a = 20, b = 3, size = n_train )
p_test = beta.rvs( a = 20, b = 3, size = n_test )
# imgs_train, imgs_test = generate_train_test_imgs( p_train, p_test )

censor_high = 17.5
y_train, delta_train, cured_train = generate_lifetimes_mpscr(poisson_spec, exp_spec, p_train, alpha,
                                                             censor_low = 0.0, censor_high = censor_high)
y_test, delta_test, cured_test = generate_lifetimes_mpscr(poisson_spec, exp_spec, p_test, alpha,
                                                          censor_low = 0.0, censor_high = censor_high)

# Take long term patients that experienced the event
# In order to properly identify a cure fraction, we specify an overall limit of 15 years
# Patients whose lifetime surpasses 15 are censored
long_term_limit = 12
long_term_train = y_train > long_term_limit
long_term_events_train = long_term_train & (delta_train == 1)

long_term_test = y_test > long_term_limit
long_term_events_test = long_term_test & (delta_test == 1)

y_train[long_term_events_train] = long_term_limit
delta_train[long_term_train] = 0
y_test[long_term_events_test] = long_term_limit
delta_test[long_term_test] = 0

fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (12,6))

km = lifelines.KaplanMeierFitter()
km.fit(y_train, delta_train)
km.plot(ax = ax[0], ci_show = True, show_censors = False, label = "Kaplan-Meier", color = "black", legend = False)

km = lifelines.KaplanMeierFitter()
km.fit(y_test, delta_test)
km.plot(ax = ax[1], ci_show = True, show_censors = False, label = "Kaplan-Meier", color = "black", legend = False)

ax[0].set_ylim(0, 1.05)
ax[1].set_ylim(0, 1.05)
plt.show()

# %% [markdown]
# # MPScr Models Simulations

# %%
# Creates the directory; does nothing if it already exists
np.random.seed(10)

# 200 replicas
poisson_spec = mpscr.MPSPoisson()
lam = 3.75
alpha = np.array([k, lam])
exp_spec = mpscr.BaseExponential()

R = 200
test_size = 0.25
n_train_values = [250, 500, 1000]

print("Generating Poisson samples")
for r in tqdm(range(R)):
    for n_train in n_train_values:
        n_test = int( n_train * test_size / (1-test_size) )
        p_train = beta.rvs( a = 20, b = 3, size = n_train )
        p_test = beta.rvs( a = 20, b = 3, size = n_test )
        imgs_train, imgs_test = generate_train_test_imgs( p_train, p_test )
        
        y_train, delta_train, cured_train = generate_lifetimes_mpscr(poisson_spec, exp_spec, p_train, alpha,
                                                                     censor_low = 0.0, censor_high = 20)
        y_test, delta_test, cured_test = generate_lifetimes_mpscr(poisson_spec, exp_spec, p_test, alpha,
                                                                  censor_low = 0.0, censor_high = 20)
        df_train = pd.DataFrame({"set": "Train", "y": y_train, "delta": delta_train, "cured": cured_train})
        df_test = pd.DataFrame({"set": "Test", "y": y_test, "delta": delta_test, "cured": cured_test})
        df = pd.concat([df_train, df_test])

        dir_name = "Simulation Data/Poisson/n{}/{}/".format(n_train, r+1)
        Path(dir_name).mkdir(parents = True, exist_ok = True)

        imgs_train = np.round( imgs_train * 30 ).astype(np.uint8)
        imgs_test = np.round( imgs_test * 30 ).astype(np.uint8)
        
        df.to_csv("{}/df.csv".format(dir_name), index = False)
        np.savez_compressed("{}/train_imgs.npz".format(dir_name), images = imgs_train)
        np.savez_compressed("{}/test_imgs.npz".format(dir_name), images = imgs_test)

# Negative Binomial (2)
negbin_spec = mpscr.MPSNegBinomial(fixed_q = 2)

print("Generating Negative Binomial samples")
for r in tqdm(range(R)):
    for n_train in n_train_values:
        n_test = int( n_train * test_size / (1-test_size) )
        p_train = beta.rvs( a = 20, b = 3, size = n_train )
        p_test = beta.rvs( a = 20, b = 3, size = n_test )
        imgs_train, imgs_test = generate_train_test_imgs( p_train, p_test )
        
        y_train, delta_train, cured_train = generate_lifetimes_mpscr(negbin_spec, exp_spec, p_train, alpha,
                                                                     censor_low = 0.0, censor_high = 20)
        y_test, delta_test, cured_test = generate_lifetimes_mpscr(negbin_spec, exp_spec, p_test, alpha,
                                                                  censor_low = 0.0, censor_high = 20)
        df_train = pd.DataFrame({"set": "Train", "y": y_train, "delta": delta_train, "cured": cured_train})
        df_test = pd.DataFrame({"set": "Test", "y": y_test, "delta": delta_test, "cured": cured_test})
        df = pd.concat([df_train, df_test])

        dir_name = "Simulation Data/Negative Binomial/n{}/{}/".format(n_train, r+1)
        Path(dir_name).mkdir(parents = True, exist_ok = True)

        imgs_train = np.round( imgs_train * 30 ).astype(np.uint8)
        imgs_test = np.round( imgs_test * 30 ).astype(np.uint8)
        
        df.to_csv("{}/df.csv".format(dir_name), index = False)
        np.savez_compressed("{}/train_imgs.npz".format(dir_name), images = imgs_train)
        np.savez_compressed("{}/test_imgs.npz".format(dir_name), images = imgs_test)
        
# Haight
print("Generating Haight samples")
# Out:
# Generating Poisson samples
#   0%|                                                                                                                                                                               | 0/200 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[56], line 22
#      19 p_test = beta.rvs( a = 20, b = 3, size = n_test )
#      20 imgs_train, imgs_test = generate_train_test_imgs( p_train, p_test )
# ---> 22 y_train, delta_train, cured_train = generate_lifetimes_mpscr(poisson_spec, exp_spec, p_train, alpha,
#      23                                                              censor_low = 0.0, censor_high = 20)
#      24 y_test, delta_test, cured_test = generate_lifetimes_mpscr(poisson_spec, exp_spec, p_test, alpha,
#      25                                                           censor_low = 0.0, censor_high = 20)
# ...
